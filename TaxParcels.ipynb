# %%
import arcpy
import os
from arcgis.gis import GIS
from arcgis.geometry import Geometry
from arcgis.geometry import Point
import pandas as pd

# %%
arcpy.env.workspace= r'C:\Users\Minoo\Documents\Internship\TaxParcelExploration\TaxParcelTooele.gdb'
arcpy.env.overwriteOutput = True

# %%
input_filename = r'parcels_Tooele_LIR_7_16_2024'

# %%
# Set local variables
inFeatures = "parcels_Tooele_LIR_7_16_2024"
fieldName1 = "TYPE"
fieldAlias = "TYPE"
fieldName2 = "SUBTYPE"
fieldName3 = "UNITCOUNT"
fieldName4 = "ACRES"
fieldName5 = "DUA"
fieldName5 = "TOTALACRAGE"
# Run AddField twice for two new fields
arcpy.management.AddField(inFeatures, fieldName1, "TEXT",
                          field_alias=fieldAlias, field_is_nullable="NULLABLE")
arcpy.management.AddField(inFeatures, fieldName2, "TEXT")
arcpy.management.AddField(inFeatures, fieldName3, "LONG")
arcpy.management.AddField(inFeatures, fieldName4, "DOUBLE")
arcpy.management.AddField(inFeatures, fieldName5, "DOUBLE")
# Out:
# <Result 'parcels_Tooele_LIR_7_16_2024'>

# %%
#TYPE = SINGLE_FAMILY
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
type_field = "TYPE"
# Define the substring to check and the value to set
check_substring = "BR01"
set_value = "SINGLE_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, type_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#TYPE = MULTI_FAMILY
# Define the field names
property_code_field = "PropertyCodes"
type_field = "TYPE"
# Define the substring to check and the value to set
check_substring = "BR01"
set_value = "MULTI_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, type_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring not in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#SUBTYPE = BRO1 == SINGLEFAMILY
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR01"
set_value = "SINGLE_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#BR01 AND BR06 (MOBILE HOME HOOKUP) == BR06
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR06"]
subtype_value = "MOBILEHOME"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)

print("Update complete.")
# Out:
# Update complete.

# %%
#BR01 AND BR08 (Manufactured) == ??
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR08"]
subtype_value = "QUESTION"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("Update complete.")
# Out:
# Update complete.

# %%
#BR01 AND BR10 (Duplex) == DUPLEX
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR10"]
subtype_value = "DUPLEX"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("Update complete.")
# Out:
# Update complete.

# %%
#BR01 AND BR12 (Outbuilding) == SINGLEFAMILY
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR12"]
subtype_value = "SINGLE_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("Update complete.")
# Out:
# Update complete.

# %%
#BR01 AND BR13 (MultipleResidences) == ??
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR13"]
subtype_value = "QUESTION"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("Update complete.")
# Out:
# Update complete.

# %%
import arcpy

# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"

# Define the field names
property_code_field = "PropertyCodes"

# Define the conditions to check
property_code_conditions = ["BR01", "BR14"]

# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")
# Out:
# PropertyCodes: BR01, BR14, LR01
# PropertyCodes: BR01, BR14, GZ4, LH01

# %%
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR01", "BR14"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")
# Out:
# PropertyCodes: BR01, BR14, LR01
# PropertyCodes: BR01, BR14, GZ4, LH01

# %%
#BR01 AND BR14 (ModularResidence) == QUESTION
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR14"]
subtype_value = "QUESTION"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("Update complete.")
# Out:
# Update complete.

# %%
#Proprty codes contain the text BR02 (Condo) and BR01 (Single family)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR01", "BR02"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR03 (Mobile Home)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR01", "BR02"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR05 (Apartment)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR05"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR06 (Mobile Home HookUp)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR06"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR07 (Garage)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR07"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR08 (Manufactured)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR08"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR09 (Parking)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR09"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR10 (Duplex)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR10"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR10 (Duplex)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR10"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR11 (Fourplex and Triplex)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR11"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR12 (Modular Residences)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR12"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR13 (Multiple Residences)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR13"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) and BR14 (Modular Residences)
# Specify the path to your feature class
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
# Define the conditions to check
property_code_conditions = ["BR02", "BR14"]
# Start a search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None:  # Check if PropertyCodes is not None
            property_code = row[0]
            # Check if all conditions are met
            if all(code in property_code for code in property_code_conditions):
                # Print the PropertyCodes
                print(f"PropertyCodes: {row[0]}")

# %%
#Proprty codes contain the text BR02 (Condo) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR02"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  905

# %%
#SUBTYPE = BRO2 == CONDO
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR02"
set_value = "CONDO"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR03 (Mobile Home) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR03", "BR06"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
#COMINE WITH BR06 == MOBILEHOME
# Out:
#  147

# %%
#SUBTYPE = BRO3 == MOBILE_HOME
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR03"
set_value = "MOBILE_HOME"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#SUBTYPE = BRO6 == MOBILE_HOME
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR06"
set_value = "MOBILE_HOME"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR04 (MixedUse_Residence) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR04"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  4

# %%
#SUBTYPE = BRO4 == MIXEDUSE_RESIDENCE
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR04"
set_value = "NULL"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR05 (Apartment) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR05"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  43

# %%
#SUBTYPE = BRO5 == APARTMENT
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR05"
set_value = "APARTMENT"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR06 (Mobile Home Hook Up) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR06"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  31

# %%
#SUBTYPE = BRO6 == MOBILE HOME HOOK UP
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR06"
set_value = "MOBILE_HOME"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR07 (Garage) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR07"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
#CHECKED - IT SEEMS LIKE A SINGLE FAMILY HOUSING
# Out:
#  1

# %%
#Proprty codes contain the text BR08 (Manufactured) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR08"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
#MANUFACTURED == SINGLE FAMILY
# Out:
#  620

# %%
#SUBTYPE = BR08 == MANUFACTURED 
# Define the field names
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the substring to check and the value to set
check_substring = "BR08"
set_value = "SINGLEFAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if the PropertyCode field is not None and contains the specified substring
        if row[0] is not None and check_substring in row[0]:
            # Set the TYPE field to the specified value
            row[1] = set_value
            # Update the row
            cursor.updateRow(row)

print("complete.")
#MANUFACTURED == SINGLE FAMILY(TYPE) - DONE
# Out:
# complete.

# %%
#SUBTYPE = BR08 AND BRO1  == QUESTION
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR01", "BR08"]
subtype_value = "QUESTION"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR09 (Parking) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR09"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  0

# %%
#Proprty codes contain the text BR10 (Duplex) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR10"]

# Initialize a counter
count = 0

# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  140

# %%
#SUBTYPE = BR10  == DUPLEX
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR10"]
subtype_value = "DUPLEX"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR11 (Fourplex AND Triplex) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR11"]
# Initialize a counter
count = 0
# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  60

# %%
#SUBTYPE = BR11  == TRIPLEX_AND_FOURPLEX
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR11"]
subtype_value = "APARTMENT"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR12 (Out Building) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR12"]
# Initialize a counter
count = 0
# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  13

# %%
#SUBTYPE = BR12  (OUTBUILDING) == QUESTION
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR12"]
subtype_value = "QUESTION"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#Proprty codes contain the text BR13 (Multiple Residences) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR13"]
# Initialize a counter
count = 0
# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  155

# %%
#SUBTYPE = BR13 ==  (MULTIPLE RESIDENCE)
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR13"]
subtype_value = "SINGLE_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
#CHECK AGAIN
# Out:
# complete.

# %%
#Proprty codes contain the text BR13 (Multiple Residences) 
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
property_code_conditions = ["BR14"]
# Initialize a counter
count = 0
# search cursor
with arcpy.da.SearchCursor(feature_class, [property_code_field]) as cursor:
    for row in cursor:
        if row[0] is not None: 
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                count += 1
# Print the number of rows that meet the conditions
print(f" {count}")
# Out:
#  33

# %%
#SUBTYPE = BR13 ==  (MULTIPLE RESIDENCE)
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR13"]
subtype_value = "MULTIPLE_RESIDENCE"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
#BR14 == SINGLE FAMILY

# %%
#SUBTYPE = BR14 ==  (MULTIPLE RESIDENCE) == SINGLE FAMILY 
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR13"]
subtype_value = "SINGLE_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
#BR14 == SINGLE FAMILY
# Out:
# complete.

# %%
#SUBTYPE = BR15 ==  Low Income == Apartment 
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR13"]
subtype_value = "TOWN_HOUSE"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#SUBTYPE = BR16 ==  Twin Home  == Apartment 
feature_class = "parcels_Tooele_LIR_7_16_2024"
# Define the field names
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"
# Define the conditions to check and the value to set
property_code_conditions = ["BR16"]
subtype_value = "SINGLE_FAMILY"
# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        if row[0] is not None:
            property_code = row[0]
            if all(code in property_code for code in property_code_conditions):
                row[1] = subtype_value
                cursor.updateRow(row)
print("complete.")
# Out:
# complete.

# %%
#finding the null values in subtype 
import arcpy

# Set the workspace
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"

# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if SUBTYPE is None (equivalent to NULL)
        if row[1] is None:
            property_code = row[0]
            # Perform the desired action here
            # Example: Print the property code of rows with NULL SUBTYPE
            print(f"PropertyCodes: {property_code}, SUBTYPE: {row[1]}")

print("Complete.")
# Out:
# PropertyCodes: GZ3, GZ4, SUBTYPE: None
# PropertyCodes: LA02, SUBTYPE: None
# PropertyCodes: LX03, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: LA02, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: LA02, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: LA02, SUBTYPE: None
# PropertyCodes: GZ3, GZ4, IT4, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: LA02, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: GZ3, SUBTYPE: None
# PropertyCodes: LX01, SUBTYPE: None
# PropertyCodes: GZ3, GZ4, SUBTYPE: None
# ...

# %%
import arcpy
# Set the workspace
feature_class = "parcels_Tooele_LIR_7_16_2024"
property_code_field = "PropertyCodes"
subtype_field = "SUBTYPE"

# Initialize a counter for NULL values
null_count = 0

# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [property_code_field, subtype_field]) as cursor:
    for row in cursor:
        # Check if SUBTYPE is None (equivalent to NULL)
        if row[1] is None:
            property_code = row[0]
            # Increment the counter for NULL values
            null_count += 1
        

print(f"Number of NULL values SUBTYPE: {null_count}")
# we should drop these?
# Out:
# Number of NULL values SUBTYPE: 1421

# %%
import arcpy

# Set the workspace
feature_class = "parcels_Tooele_LIR_7_16_2024"
subtype_field = "SUBTYPE"

# Initialize a counter for NULL values
null_count = 0

# Start an update cursor
with arcpy.da.UpdateCursor(feature_class, [subtype_field]) as cursor:
    for row in cursor:
        # Check if SUBTYPE is None (equivalent to NULL)
        if row[0] is None:
            # Increment the counter for NULL values
            null_count += 1

print(f"Number of NULL values in SUBTYPE: {null_count}")
# Out:
# Number of NULL values in SUBTYPE: 12290

# %%
# do the spatial join first and then check the multi family housings to make sure it's correct 
# multi family
#make sure it's not a hotel 
# temporary commercial - mobile homes
#KOA campgrunds - mobile homes- it marks like a hotel in google maps 
# add another field "Review" - use 1 and 0 to show which ones have you looked at 
# name join count and change the filed name to "Unit_Count_AP" - The working unit count field
# make another field and make it unit count and check all the multi family to make sure
